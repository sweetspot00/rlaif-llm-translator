# %%
import json, re
from pathlib import Path
import numpy as np
import pandas as pd

repo_root = Path("/Users/wanchunni/Documents/code/rlaif-llm-translator")  # set to your repo root
scene_slug = "37_millennium"

metrics_dir = repo_root / f"sim/results/{scene_slug}/metrics"
context_path = repo_root / f"preprocess/preprocessed_scene/{scene_slug}/preprocessed.jsonl"

if not context_path.exists():
    raise FileNotFoundError(f"Context file not found: {context_path}")
if not metrics_dir.exists():
    raise FileNotFoundError(f"Metrics dir not found: {metrics_dir}")

# Load context rows keyed by scene_index
contexts = {}
with context_path.open() as f:
    for line in f:
        ctx = json.loads(line)
        contexts[int(ctx["scene_index"])] = ctx

# Obstacle counter (first array in npz; tweak key if needed)
_obstacle_cache = {}
def count_obstacles(npz_path: Path):
    npz_path = npz_path.resolve()
    if npz_path in _obstacle_cache:
        return _obstacle_cache[npz_path]
    with np.load(npz_path, allow_pickle=True) as data:
        first_key = next(iter(data.files))
        _obstacle_cache[npz_path] = len(data[first_key])
    return _obstacle_cache[npz_path]

rows = []
for mfile in sorted(metrics_dir.glob("metrics_*.json")):
    m = re.search(r"metrics_(\d+)_", mfile.name)
    if not m:
        continue
    context_id = int(m.group(1))
    ctx = contexts.get(context_id, {})
    metrics_blob = json.loads(mfile.read_text())

    assets = ctx.get("assets", {}) or {}
    obstacle_path = assets.get("anchored_obstacles")
    map_obstacle_count = count_obstacles(repo_root / obstacle_path) if obstacle_path else None

    rows.append({
        "scene_name": ctx.get("scene_id"),
        "context_id": context_id,
        "category": ctx.get("category"),
        "crowd_size": ctx.get("crowd_size"),
        "scenario": ctx.get("scenario"),
        "goal_cnt": len(ctx.get("goals_px", [])),
        "groups": len(ctx.get("groups", [])),
        "toward_event_center": ctx.get("towards_event"),
        "map_obstacle_count": map_obstacle_count,
        **metrics_blob.get("metrics", {}),
    })

df = pd.DataFrame(rows)
metric_cols = [c for c in df.columns if c not in ["scene_name","context_id","category","crowd_size","scenario","goal_cnt","groups","toward_event_center","map_obstacle_count"]]
df[metric_cols] = df[metric_cols].apply(pd.to_numeric, errors="coerce")
df
# Out:
#                                          scene_name  context_id  \
# 0   37_Millennium_Park_simplified_obstacle_anchored           0
# 1   37_Millennium_Park_simplified_obstacle_anchored           1
# 2   37_Millennium_Park_simplified_obstacle_anchored           2
# 3   37_Millennium_Park_simplified_obstacle_anchored           3
# 4   37_Millennium_Park_simplified_obstacle_anchored           4
# 5   37_Millennium_Park_simplified_obstacle_anchored           5
# 6   37_Millennium_Park_simplified_obstacle_anchored           6
# 7   37_Millennium_Park_simplified_obstacle_anchored           7
# 8   37_Millennium_Park_simplified_obstacle_anchored           8
# 9   37_Millennium_Park_simplified_obstacle_anchored           9
# 10  37_Millennium_Park_simplified_obstacle_anchored          10
# 11  37_Millennium_Park_simplified_obstacle_anchored          11
# 12  37_Millennium_Park_simplified_obstacle_anchored          12
# 13  37_Millennium_Park_simplified_obstacle_anchored          13
# 14  37_Millennium_Park_simplified_obstacle_anchored          14
# 15  37_Millennium_Park_simplified_obstacle_anchored          15
# 16  37_Millennium_Park_simplified_obstacle_anchored          16
# 17  37_Millennium_Park_simplified_obstacle_anchored          17
# 18  37_Millennium_Park_simplified_obstacle_anchored          18
# 19  37_Millennium_Park_simplified_obstacle_anchored          20
# 20  37_Millennium_Park_simplified_obstacle_anchored          21
# 21  37_Millennium_Park_simplified_obstacle_anchored          22
# 22  37_Millennium_Park_simplified_obstacle_anchored          23
# 23  37_Millennium_Park_simplified_obstacle_anchored          24
# 24  37_Millennium_Park_simplified_obstacle_anchored          25
# 25  37_Millennium_Park_simplified_obstacle_anchored          26
# 26  37_Millennium_Park_simplified_obstacle_anchored          27
# 27  37_Millennium_Park_simplified_obstacle_anchored          28
# 28  37_Millennium_Park_simplified_obstacle_anchored          29
# 29  37_Millennium_Park_simplified_obstacle_anchored          30
# 30  37_Millennium_Park_simplified_obstacle_anchored          31
# 31  37_Millennium_Park_simplified_obstacle_anchored          32
# 32  37_Millennium_Park_simplified_obstacle_anchored          33
# 33  37_Millennium_Park_simplified_obstacle_anchored          34
# 34  37_Millennium_Park_simplified_obstacle_anchored          35
# 35  37_Millennium_Park_simplified_obstacle_anchored          36
# 36  37_Millennium_Park_simplified_obstacle_anchored          37
# 37  37_Millennium_Park_simplified_obstacle_anchored          38
# 38  37_Millennium_Park_simplified_obstacle_anchored          39
# 39  37_Millennium_Park_simplified_obstacle_anchored          40
# 40  37_Millennium_Park_simplified_obstacle_anchored          41
# 41  37_Millennium_Park_simplified_obstacle_anchored          42
# 42  37_Millennium_Park_simplified_obstacle_anchored          43
# 43  37_Millennium_Park_simplified_obstacle_anchored          44
# 44  37_Millennium_Park_simplified_obstacle_anchored          45
# 45  37_Millennium_Park_simplified_obstacle_anchored          46
# 46  37_Millennium_Park_simplified_obstacle_anchored          47
# 47  37_Millennium_Park_simplified_obstacle_anchored          48
# 48  37_Millennium_Park_simplified_obstacle_anchored          49
# 49  37_Millennium_Park_simplified_obstacle_anchored          50
# 50  37_Millennium_Park_simplified_obstacle_anchored          51
# 51  37_Millennium_Park_simplified_obstacle_anchored          52
# 52  37_Millennium_Park_simplified_obstacle_anchored          53
# 53  37_Millennium_Park_simplified_obstacle_anchored          54
# 54  37_Millennium_Park_simplified_obstacle_anchored          56
# 55  37_Millennium_Park_simplified_obstacle_anchored          57
# 56  37_Millennium_Park_simplified_obstacle_anchored          58
# 57  37_Millennium_Park_simplified_obstacle_anchored          59
#
#          category  crowd_size  \
# 0      Ambulatory         192
# 1      Ambulatory          62
# 2      Ambulatory         296
# 3      Ambulatory          80
# 4      Ambulatory         160
# 5      Ambulatory          82
# 6      Ambulatory          66
# 7      Ambulatory          44
# 8      Ambulatory          90
# 9      Ambulatory         315
# 10     Disability          79
# 11     Disability          70
# 12     Disability          41
# 13     Disability          71
# 14     Disability          80
# 15     Disability          45
# 16     Disability          49
# 17     Disability          83
# 18     Disability          13
# 19       Cohesive          98
# 20       Cohesive         196
# 21       Cohesive          72
# 22       Cohesive          68
# 23       Cohesive         274
# 24       Cohesive          50
# 25     Expressive          61
# 26     Expressive         316
# 27     Expressive          94
# 28     Expressive         199
# 29     Expressive           2
# 30     Expressive          88
# 31     Expressive          19
# 32  Participatory         198
# 33  Participatory          94
# 34  Participatory         183
# 35  Participatory          60
# 36  Participatory         231
# 37  Participatory          90
# 38  Participatory          46
# 39     Aggressive          90
# 40     Aggressive          43
# 41     Aggressive          99
# 42     Aggressive          51
# 43     Aggressive          86
# 44     Aggressive          15
# 45     Aggressive          15
# 46   Demonstrator         225
# 47   Demonstrator         389
# 48   Demonstrator          57
# 49   Demonstrator         204
# 50   Demonstrator          73
# 51   Demonstrator         329
# 52   Demonstrator          74
# 53   Demonstrator           6
# 54       Escaping         331
# 55       Escaping          83
# 56       Escaping          90
# 57       Escaping           3
#
#                                              scenario  goal_cnt  groups  \
# 0   Late-morning strolls at Millennium Park: visit...         6      29
# 1   Warm afternoon foot traffic: small groups wand...         5       7
# 2   Evening promenade: visitors take photos and me...         6      45
# 3   Weekend leisure walkers spread through the ope...         5      12
# 4   Morning walkers and joggers circulate gently t...         6      28
# 5   Light sightseeing flow: families and friends w...         5      14
# 6   Photography enthusiasts wander slowly through ...         5      12
# 7   Casual visitors spread thinly across paths, lo...         5       7
# 8   Lunchtime drift: office workers cross the park...         6      12
# 9   Early evening ambient flow: couples and small ...         6      53
# 10  Accessible day at the park: wheelchair users a...         5      13
# 11  Inclusive garden tour: a guided group with mob...         4      11
# 12  Quiet morning accessibility program: participa...         4       5
# 13  Adaptive fitness session: participants with di...         4      15
# 14  Community accessibility walk: volunteers accom...         4      13
# 15  Sensory-friendly hour: attendees move slowly a...         3       5
# 16  Wheelchair photo meet-up: participants roll to...         3       6
# 17  Low-impact community stroll: seniors and careg...         4      12
# 18  Inclusive arts stop: participants with canes m...         3       2
# 19  Cohesive alumni meet-up: a few large groups he...         3      19
# 20  Coordinated school field trip: chaperoned clus...         4      37
# 21  Cohesive family reunion: two main groups trave...         3      10
# 22  Coordinated photography walk: guided clusters ...         3       9
# 23  Cohesive cultural tour: groups proceed togethe...         4      42
# 24  Guided architecture walk: two cohesive cluster...         3       8
# 25  Pop-up music and dance: an expressive crowd ro...         5      10
# 26  Street performers draw an expressive crowd tha...         5      53
# 27  Chalk art jam: expressive participants wander,...         4      13
# 28  Interactive bubble show: expressive visitors d...         4      33
# 29  Pop-up poetry circle: expressive crowd mills s...         3       0
# 30  Community mural unveiling: participants pause ...         4      16
# 31  Outdoor sketch circle: expressive crowd moves ...         3       2
# 32  Community yoga session: participants gather ne...         4      37
# 33  Interactive garden workshop: participants move...         4      12
# 34  Photography scavenger hunt: teams collect prom...         4      33
# 35  Community games: participants pick up equipmen...         4      10
# 36  Interactive science booth day: attendees gathe...         4      38
# 37  Hands-on art stations: participants collect ma...         4      16
# 38  Interactive map hunt: pairs collect clues at t...         3       8
# 39  Heated argument near a food cart spills over; ...         4      14
# 40  Tense dispute over saved seats causes jostling...         3       6
# 41  Raised voices at the north promenade draw a ci...         4      17
# 42  A vendor dispute escalates; some approach whil...         4       8
# 43  A heated debate about access lines turns pushy...         4      17
# 44  A loud confrontation draws a ring of people; m...         3       3
# 45  Small scuffle breaks out near the north corrid...         3       2
# 46  Impromptu rally forms near the west plaza; dem...         4      31
# 47  Climate-themed march gathers at the north prom...         4      64
# 48  Labor rally assembles at the east corridor and...         3      11
# 49  Human-rights demonstration starts at the west ...         4      38
# 50  Peace vigil forms at the north promenade and m...         4      13
# 51  Public art funding rally steps off from the ea...         4      56
# 52  Health care march: participants form lines at ...         3      13
# 53  Pop-up awareness rally gathers at the north pr...         3       2
# 54  Sudden lightning crack and heavy rain startle ...         4      54
# 55  A loud crack from a stage rig prompts a quick ...         4      14
# 56  A sudden swarm of bees appears near the west p...         4      16
# 57  Amplifier smoke at the north promenade trigger...         4       0
#
#    toward_event_center  map_obstacle_count  ADE  ...  CollisionRate  VD  DDS  \
# 0               random                  88  NaN  ...       0.005828 NaN  NaN
# 1               random                  88  NaN  ...       0.017381 NaN  NaN
# 2               random                  88  NaN  ...       0.006559 NaN  NaN
# 3               random                  88  NaN  ...       0.009270 NaN  NaN
# 4               random                  88  NaN  ...       0.010409 NaN  NaN
# 5               random                  88  NaN  ...       0.013226 NaN  NaN
# 6               random                  88  NaN  ...       0.013922 NaN  NaN
# 7               random                  88  NaN  ...       0.024336 NaN  NaN
# 8               random                  88  NaN  ...       0.008479 NaN  NaN
# 9               random                  88  NaN  ...       0.007758 NaN  NaN
# 10                True                  88  NaN  ...       0.003595 NaN  NaN
# 11                True                  88  NaN  ...       0.014111 NaN  NaN
# 12                True                  88  NaN  ...       0.007532 NaN  NaN
# 13                True                  88  NaN  ...       0.006519 NaN  NaN
# 14                True                  88  NaN  ...       0.005632 NaN  NaN
# 15                True                  88  NaN  ...       0.007096 NaN  NaN
# 16                True                  88  NaN  ...       0.016827 NaN  NaN
# 17                True                  88  NaN  ...       0.004621 NaN  NaN
# 18                True                  88  NaN  ...       0.076052 NaN  NaN
# 19                True                  88  NaN  ...       0.018150 NaN  NaN
# 20                True                  88  NaN  ...       0.010268 NaN  NaN
# 21                True                  88  NaN  ...       0.005456 NaN  NaN
# 22                True                  88  NaN  ...       0.014655 NaN  NaN
# 23                True                  88  NaN  ...       0.009005 NaN  NaN
# 24                True                  88  NaN  ...       0.021087 NaN  NaN
# 25                True                  88  NaN  ...       0.011771 NaN  NaN
# 26                True                  88  NaN  ...       0.004620 NaN  NaN
# 27                True                  88  NaN  ...       0.005181 NaN  NaN
# 28                True                  88  NaN  ...       0.004443 NaN  NaN
# 29                True                  88  NaN  ...       0.000000 NaN  NaN
# 30                True                  88  NaN  ...       0.010393 NaN  NaN
# 31                True                  88  NaN  ...       0.032579 NaN  NaN
# 32                True                  88  NaN  ...       0.008820 NaN  NaN
# 33                True                  88  NaN  ...       0.007084 NaN  NaN
# 34                True                  88  NaN  ...       0.010773 NaN  NaN
# 35                True                  88  NaN  ...       0.011045 NaN  NaN
# 36                True                  88  NaN  ...       0.004626 NaN  NaN
# 37                True                  88  NaN  ...       0.009061 NaN  NaN
# 38                True                  88  NaN  ...       0.032980 NaN  NaN
# 39              random                  88  NaN  ...       0.056535 NaN  NaN
# 40              random                  88  NaN  ...       0.022939 NaN  NaN
# 41              random                  88  NaN  ...       0.049944 NaN  NaN
# 42              random                  88  NaN  ...       0.082104 NaN  NaN
# 43              random                  88  NaN  ...       0.145117 NaN  NaN
# 44              random                  88  NaN  ...       0.070759 NaN  NaN
# 45              random                  88  NaN  ...       0.155579 NaN  NaN
# 46                True                  88  NaN  ...       0.006744 NaN  NaN
# 47                True                  88  NaN  ...       0.003742 NaN  NaN
# 48                True                  88  NaN  ...       0.068154 NaN  NaN
# 49                True                  88  NaN  ...       0.005818 NaN  NaN
# 50                True                  88  NaN  ...       0.007207 NaN  NaN
# 51                True                  88  NaN  ...       0.007497 NaN  NaN
# 52                True                  88  NaN  ...       0.023631 NaN  NaN
# 53                True                  88  NaN  ...       0.000000 NaN  NaN
# 54               False                  88  NaN  ...       0.114805 NaN  NaN
# 55               False                  88  NaN  ...       0.038124 NaN  NaN
# 56               False                  88  NaN  ...       0.056780 NaN  NaN
# 57               False                  88  NaN  ...       0.000000 NaN  NaN
#
#     GoalRate  goal_achieve_as_long_as_pass_by  SocialDistanceViolations  \
# 0   0.619792                         0.692708                  0.021537
# 1   0.741935                         0.758065                  0.048964
# 2   0.655405                         0.722973                  0.019196
# 3   0.650000                         0.700000                  0.051210
# 4   0.593750                         0.700000                  0.020483
# 5   0.707317                         0.743902                  0.057417
# 6   0.590909                         0.636364                  0.045884
# 7   0.977273                         0.977273                  0.165072
# 8   0.588889                         0.677778                  0.030117
# 9   0.714286                         0.812698                  0.019123
# 10  0.569620                         0.632911                  0.023592
# 11  0.642857                         0.757143                  0.047725
# 12  0.609756                         0.634146                  0.063636
# 13  0.577465                         0.647887                  0.030428
# 14  0.675000                         0.750000                  0.037165
# 15  0.733333                         0.777778                  0.063634
# 16  0.795918                         0.795918                  0.082112
# 17  0.626506                         0.674699                  0.031753
# 18  1.000000                         1.000000                  0.232922
# 19  0.816327                         0.836735                  0.036117
# 20  0.576531                         0.632653                  0.017116
# 21  0.625000                         0.666667                  0.025283
# 22  0.647059                         0.661765                  0.030880
# 23  0.708029                         0.740876                  0.018374
# 24  0.760000                         0.780000                  0.042749
# 25  0.639344                         0.672131                  0.024122
# 26  0.718354                         0.775316                  0.009356
# 27  0.744681                         0.776596                  0.021921
# 28  0.703518                         0.758794                  0.011971
# 29  1.000000                         1.000000                  0.000000
# 30  0.670455                         0.761364                  0.026366
# 31  0.736842                         0.736842                  0.081369
# 32  0.636364                         0.727273                  0.046420
# 33  0.734043                         0.819149                  0.032871
# 34  0.601093                         0.644809                  0.024840
# 35  0.566667                         0.600000                  0.023696
# 36  0.536797                         0.588745                  0.011824
# 37  0.600000                         0.622222                  0.026161
# 38  0.565217                         0.565217                  0.051280
# 39  0.600000                         0.666667                  0.080197
# 40  0.418605                         0.418605                  0.030275
# 41  0.767677                         0.838384                  0.063341
# 42  0.862745                         0.882353                  0.098870
# 43  0.930233                         0.930233                  0.210469
# 44  0.600000                         0.666667                  0.084128
# 45  0.733333                         0.733333                  0.173694
# 46  0.635556                         0.644444                  0.013734
# 47  0.560411                         0.663239                  0.009603
# 48  0.807018                         0.824561                  0.092238
# 49  0.730392                         0.779412                  0.025388
# 50  0.438356                         0.493151                  0.029381
# 51  0.686930                         0.765957                  0.015385
# 52  0.743243                         0.770270                  0.038869
# 53  0.333333                         0.333333                  0.000000
# 54  0.791541                         0.839879                  0.162187
# 55  0.566265                         0.590361                  0.047801
# 56  0.588889                         0.677778                  0.060512
# 57  1.000000                         1.000000                  0.000000
#
#     towards_event_achieve_rate  away_event_achieve_rate  group_stick_together  \
# 0                          NaN                      NaN              0.000000
# 1                          NaN                      NaN              0.000000
# 2                          NaN                      NaN              0.061115
# 3                          NaN                      NaN              0.080280
# 4                          NaN                      NaN              0.092819
# 5                          NaN                      NaN              0.174741
# 6                          NaN                      NaN              0.000000
# 7                          NaN                      NaN              0.000000
# 8                          NaN                      NaN              0.000000
# 9                          NaN                      NaN              0.101605
# 10                    0.518987                      NaN              0.063445
# 11                    0.528571                      NaN              0.136636
# 12                    0.365854                      NaN              0.000000
# 13                    0.535211                      NaN              0.056185
# 14                    0.800000                      NaN              0.124686
# 15                    0.577778                      NaN              0.164424
# 16                    0.224490                      NaN              0.146791
# 17                    0.614458                      NaN              0.040195
# 18                    0.153846                      NaN              0.000000
# 19                    0.142857                      NaN              0.212876
# 20                    0.642857                      NaN              0.116283
# 21                    0.166667                      NaN              0.083411
# 22                    0.455882                      NaN              0.000000
# 23                    0.401460                      NaN              0.176168
# 24                    0.280000                      NaN              0.114590
# 25                    0.524590                      NaN              0.000000
# 26                    0.731013                      NaN              0.127286
# 27                    0.744681                      NaN              0.203967
# 28                    0.608040                      NaN              0.123877
# 29                    0.500000                      NaN                   NaN
# 30                    0.693182                      NaN              0.193871
# 31                    0.210526                      NaN              0.355097
# 32                    0.666667                      NaN              0.097971
# 33                    0.425532                      NaN              0.135743
# 34                    0.775956                      NaN              0.095714
# 35                    0.566667                      NaN              0.082278
# 36                    0.640693                      NaN              0.091483
# 37                    0.377778                      NaN              0.168804
# 38                    0.760870                      NaN              0.093688
# 39                         NaN                      NaN              0.066146
# 40                         NaN                      NaN              0.000000
# 41                         NaN                      NaN              0.165066
# 42                         NaN                      NaN              0.545220
# 43                         NaN                      NaN              0.215895
# 44                         NaN                      NaN              0.276038
# 45                         NaN                      NaN              0.000000
# 46                    0.373333                      NaN              0.111968
# 47                    0.506427                      NaN              0.042357
# 48                    0.631579                      NaN              0.477379
# 49                    0.602941                      NaN              0.218468
# 50                    0.657534                      NaN              0.000000
# 51                    0.693009                      NaN              0.128605
# 52                    0.567568                      NaN              0.270691
# 53                    0.166667                      NaN              0.000000
# 54                         NaN                 0.178248              0.261838
# 55                         NaN                 0.265060              0.068193
# 56                         NaN                 0.511111              0.115548
# 57                         NaN                 1.000000                   NaN
#
#     group_goal_achievement
# 0                 0.000000
# 1                 0.000000
# 2                 0.088889
# 3                 0.083333
# 4                 0.107143
# 5                 0.214286
# 6                 0.083333
# 7                 1.000000
# 8                 0.000000
# 9                 0.150943
# 10                0.153846
# 11                0.181818
# 12                0.000000
# 13                0.066667
# 14                0.153846
# 15                0.200000
# 16                0.166667
# 17                0.083333
# 18                1.000000
# 19                0.578947
# 20                0.135135
# 21                0.100000
# 22                0.000000
# 23                0.238095
# 24                0.125000
# 25                0.100000
# 26                0.207547
# 27                0.307692
# 28                0.151515
# 29                     NaN
# 30                0.250000
# 31                0.500000
# 32                0.135135
# 33                0.166667
# 34                0.151515
# 35                0.100000
# 36                0.131579
# 37                0.187500
# 38                0.125000
# 39                0.142857
# 40                0.000000
# 41                0.176471
# 42                0.625000
# 43                0.823529
# 44                0.333333
# 45                0.000000
# 46                0.129032
# 47                0.125000
# 48                0.545455
# 49                0.447368
# 50                0.000000
# 51                0.160714
# 52                0.384615
# 53                0.000000
# 54                0.351852
# 55                0.071429
# 56                0.125000
# 57                     NaN
#
# [58 rows x 23 columns]

# %%
import pandas as pd
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go

x_cols = ["category", "crowd_size", "goal_cnt", "toward_event_center", "map_obstacle_count"]
y_metrics = [
    "goal_achieve_as_long_as_pass_by",
    "away_event_achieve_rate",
    "towards_event_achieve_rate",
    "CollisionRate",
    "group_goal_achievement",
    "SocialDistanceViolations",
]

palette = px.colors.qualitative.Set2
fig = make_subplots(rows=len(x_cols), cols=1, shared_xaxes=False,
                    subplot_titles=[f"{xc} vs metrics" for xc in x_cols])

for i, xcol in enumerate(x_cols, start=1):
    grouped = df.groupby(xcol)[y_metrics].mean().reset_index()
    if pd.api.types.is_numeric_dtype(grouped[xcol]):
        grouped = grouped.sort_values(by=xcol)
    else:
        grouped = grouped.sort_values(by=xcol, key=lambda s: s.astype(str))

    for j, m in enumerate(y_metrics):
        fig.add_trace(
            go.Scatter(
                x=grouped[xcol],
                y=grouped[m],
                mode="lines+markers",
                name=m if i == 1 else None,  # show legend only once
                line=dict(color=palette[j % len(palette)], width=2),
                marker=dict(size=7),
                hovertemplate=f"{xcol}=%{{x}}<br>{m}=%{{y:.3f}}<extra></extra>",
            ),
            row=i, col=1,
        )
    fig.update_xaxes(title_text=xcol, row=i, col=1)
    fig.update_yaxes(title_text="mean metric", row=i, col=1)

fig.update_layout(
    height=300 * len(x_cols),
    title="Metrics vs X variables",
    legend_title="Metric",
    hovermode="x unified",
    template="plotly_white",
)
fig.show()
